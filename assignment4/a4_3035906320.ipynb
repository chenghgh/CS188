# %% [markdown]
# # COMP7404 - Assignment 4
#
# ## Part A: Conceptual Questions
#
# Solve the following questions by hand. No need to implement any code.

# %% [markdown]
# ### A1
# Consider a Perceptron with 2 inputs and 1 output. Let the weights of the Perceptron be $w_1 = 1$ and $w_2 = 1$ and let the bias be $w_0 = -1.5$. Calculate the output of the following inputs:(0, 0), (1, 0), (0, 1), (1, 1)

# %% [markdown]
# Perceptron output (-1, 1)
#
#
# input: (0,0) output: -1
#
#
# input: (1,0) output: -1
#
# input: (0,1) output: -1
#
#
# input: (1,1) output: 1

# %% [markdown]
# ###A2
# Define a perceptron for the following logical functions: AND, NOT, NAND, NOR

# %% [markdown]
# Perceptron output: (0, 1)
#
# $$
# \begin{align}
# \text{AND}:
# 𝜙(z) &= \begin{cases}
# 1 & z=x_1+x_2-1>0\\
# 0 & otherwise \\
# \end{cases} \\
# \text{NOT}:
# 𝜙(z) &= \begin{cases}
# 1 & z=-1\times x_1+1>0\\
# 0 & otherwise
# \end{cases}\\
# \text{NAND}:
# 𝜙(z) &= \begin{cases}
# 1 & z=-1\times x_1+ (-1)\times x_2 + 2>0\\
# 0 & otherwise
# \end{cases} \\
# \text{NOR}:
# 𝜙(z) &= \begin{cases}
# 1 & z=-1\times x_1+ (-1)\times x_2 + 1>0\\
# 0 & otherwise
# \end{cases} \\
# \end{align}
# $$

# %% [markdown]
# ###A3
# The parity problem returns 1 if the number of inputs that are 1 is even, and 0 otherwise. Can a perceptron learn this problem for 3 inputs?

# %% [markdown]
# *Your answer here*
#
# No

# %% [markdown]
# ###A4
# Suppose that the following are a set of point in two classes:
#
# *   Class1: $(1, 1), (1, 2), (2, 1)$
# *   Class2: $(0, 0), (1, 0), (0, 1)$
#
# Plot them and find the optimal separating line. What are the support vectors, and what is the meaning?

# %% [markdown]
# *Your answer here*
#
# Line: -x + 1.5 = y
#
# Support vector: (0, 1), (1, 0), (1, 1)
#
# They are the samples located on the edge of the street to determine the decision boundary.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot((1,1,2),(1,2,1), 'ro')
plt.plot((0,1,0),(0,0,1), 'bo')
x = list(np.arange(-1, 3, 0.1))
y = [-i+1.5 for i in x]
plt.plot(x, y, 'g-')
plt.show()

# %% [markdown]
# ###A5
# Suppose that the probability of five events are $P(first) = 0.5, P(second) = P(third) = P(fourth) = P(fifth) = 0.125$. Calculate the entropy and write down in words what this means.

# %% [markdown]
# *Your answer here* \
# $I_H(t) = -\sum_{i=1}^5 p(i|t)\log_{2}p(i|t) = 2$
#
# It means the uncertainty. When the entropy is high, there are more possible states in the event set. And the probability of each event is not very high.

# %% [markdown]
# ###A6
# Design a decision tree that computes the logical AND function. How does it compare to the Perceptron solution?

# %% [markdown]
# *Your answer here*
# $$
# \begin{array}{c|cccc}
# n & x_1 & x_2 & output \\
# \hline
# 1 & 0 & 0 & 0 \\
# 2 & 0 & 1 & 0 \\
# 3 & 1 & 0 & 0 \\
# 4 & 1 & 1 & 1
# \end{array}
# $$

# %% [markdown]
# ![WechatIMG138.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###A7
# Turn the following politically incorrect data into a decision tree to classify which attributes make a person attractive, and then extract the rules. Use the Gini Impurity.
#
# | Height  | Hair  | Eyes  | Attractive?  |
# |:-:|:-:|:-:|:-:|
# | Small  | Blonde  | Brown  | No  |
# | Tall  | Dark  | Brown  | No  |
# | Tall  | Blonde  | Blue  | Yes  |
# | Tall  | Dark  | Blue  | No  |
# | Small  | Dark  | Blue  | No  |
# | Tall  | Red  | Blue  | Yes  |
# | Tall  | Blonde  | Brown  | No  |
# | Small  | Blonde  | Blue  | Yes  |

# %% [markdown]
# *Your answer here*
#
# suppose the decision tree just answer yes or no.
#
# $$
# \begin{align}
# (1,2,3,4,5,6,7,8) \\
# \text{y} \diagup \text{Eyes==Brown?} \diagdown \text{n} \\
# (1,2,7) \quad\quad\quad (3,4,5,6,8) \\
# \quad\quad\quad\quad\quad\quad \text{y} \diagup \text{Hair == Dark?} \diagdown \text{n} \\
# \quad\quad\quad\quad(4,5)\quad\quad\quad(3,6,8)
# \end{align}
# $$
#
#
# (1,2,3,4,5,6,7,8) Eyes==Brown? (1,2,7) (3,4,5,6,8)
#
#
# (3,4,5,6,8) Hair==Dark? (4,5) (3,6,8)
#
# From this figure, Brown eyes and Dark hair with Brown eyes are not attractive

# %% [markdown]
# ###A8
# Suppose we collect data for a group of students in a postgraduate machine learning class with features $x_1$ = hours studies, $x_2$ = undergraduate GPA and label $y$ = receive an A. We fit a logistic regression and produce estimated weights as follows: $w_0 = -6$, $w_1 = 0.05$, $w_2 = 1$.
#
# 1.  Estimate the probability that a student who studies for 40h and has an undergraduate GPA of 3.5 gets an A in the class
# 2.  How many hours would the student in part 1. need to study to have a 50% chance of getting an A in the class?

# %% [markdown]
# *Your answer here*
#
# 1. The probability is $\frac{1}{1+e^{-(-0.5)}}$
#
#
# > z = 40*0.05+3.5-6=-0.5
#
# 2. 50h

# %% [markdown]
# ###A9
# Suppose that we take a data set, divide it into equally-sized training and test sets, and then try out two different classification procedures. First we use logistic regression and get an error rate of 20% on the training data and 30% on the test data. Next we use 1-nearest neighbors (i.e., K=1) and get an average error rate (averaged over both test and training data sets) of 18%. Based on these results, which method should we prefer to use for classification of new observations? Why?

# %% [markdown]
# *Your answer here*
#
# We should prefer to use logistic regression.
#
# For the 1-nearest neighbors, the training error is zero which is badly overfitting. We got an average error rate of 18% in the case, so the test error rate is 36%, which is larger than the logistic regression error rate.

# %% [markdown]
# ### A10
#
# Suppose the features in your training set have very different scales. Which algorithms discussed in class might suffer from this, and how? What can you do about it?

# %% [markdown]
# *Your answer here*
#
# If the features in our training set have very different scales, the Gradient Descent algorithm may suffer from this. The cost function may need a very long time to coverge. In order to avoid this, we can use Standardization method to the training dataset.

# %% [markdown]
# ### A11
#
#
# If your AdaBoost ensemble underfits the training data, which hyperparameters should you tweak and how?

# %% [markdown]
# *Your answer here
#
# If the AdaBoost ensemble underfits the training data, we can try to increase the number of estimators or reducing the regulization of the base estimators. We can also slightly increase the learning rate.

# %% [markdown]
# ### A12
#
# What is the benefit of out-of-bag evaluation?

# %% [markdown]
# *Your answer here*
#
# It will use the data which is not trained to evaluate each predictor in a bagging ensemble. So it does'n need to have an additional validation set. We will have more data for training and the model can perform slightly better.

# %% [markdown]
# ### A13
#
# What is the difference between hard and soft voting classifiers?

# %% [markdown]
# *Your answer here*
#
# Hard voting is that every individual classifier votes for a class, and the majority wints.
#
# Soft voting is that every individual classifier provides a probability.  Then the predictions are weighted by the classifiers' importance and summed up.

# %% [markdown]
# ## Part B: Applied Questions
#
# Solve the following questions by implementing solutions in code.

# %% [markdown]
# ###B1
# Consider the following Perceptron code.

# %%
import numpy as np

class Perceptron(object):
    """Perceptron classifier.

    Parameters
    ------------
    eta : float
        Learning rate (between 0.0 and 1.0)
    n_iter : int
        Passes over the training dataset.

    Attributes
    -----------
    w_ : 1d-array
        Weights after fitting. one for w0
    errors_ : list
        Number of misclassifications in every epoch.

    """
    def __init__(self, eta=0.01, n_iter=10):
        self.eta = eta
        self.n_iter = n_iter

    def fit(self, X, y):
        """Fit training data.

        Parameters
        ----------
        X : {array-like}, shape = [n_samples, n_features]
            Training vectors, where n_samples is the number of samples and
            n_features is the number of features.
        y : array-like, shape = [n_samples]
            Target values.

        Returns
        -------
        self : object

        """
        self.w_ = np.zeros(1 + X.shape[1])
        self.errors_ = []

        for _ in range(self.n_iter):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))
                self.w_[1:] += update * xi
                self.w_[0] += update
                errors += int(update != 0.0)
            self.errors_.append(errors)
        return self

    def net_input(self, X):
        """Calculate net input"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        """Return class label after unit step"""
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# %%
import pandas as pd

data_src = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

df = pd.read_csv(data_src, header=None)

df.tail()
# Out:
#        0    1    2    3               4
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# select setosa and versicolor
y = df.iloc[0:100, 4].values
y = np.where(y == 'Iris-setosa', -1, 1)

# extract sepal length and petal length
X = df.iloc[0:100, [0, 2]].values

# plot data
plt.scatter(X[:50, 0], X[:50, 1],
            color='red', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1],
            color='blue', marker='x', label='versicolor')

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
ppn = Perceptron(eta=0.1, n_iter=10)
ppn = ppn.fit(X, y)

# %%
from matplotlib.colors import ListedColormap

from matplotlib.colors import ListedColormap
def plot_decision_regions(X, y, classifier, resolution=0.01):
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

# %% [markdown]
# As shown in function plot_decision_regions, the decision regions can be visualized by dense sampling via meshgrid. However, if the grid resolution is not enough, as artificially set below, the boundary will appear inaccurate.
#
# Implement function plot_decision_boundary below to analytically compute and plot the decision boundary.

# %%
def plot_decision_boundary(X, y, classifier):    
    
    # replace the two lines below with your code
    # x1_interval = [X[:, 0].min() - 1, X[:, 0].max() + 1]
    # x2_interval = [X[:, 1].min() - 1, X[:, 1].max() + 1]
    # print(x1_interval)
    # print(x2_interval)
    x1_interval = [X[:, 0].min() - 1, X[:, 0].max() + 1]
    w = classifier.w_
    x2_interval = [-(w[0] + w[1]*x1_interval[0])/w[2] , -(w[0] + w[1]*x1_interval[1])/w[2]]
    plt.plot(x1_interval, x2_interval, color='green', linewidth=4, label='boundary')

# %%
low_res = 0.1 # intentional for this exercise
plot_decision_regions(X, y, classifier=ppn, resolution=low_res)
plot_decision_boundary(X, y, classifier=ppn)
plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###B2
#
# In class we applied different scikit-learn classifers for the Iris data set.
#
# In this question, we will apply the same set of classifiers over a different data set: hand-written digits.
# Please write down the code for different classifiers, choose their hyper-parameters, and compare their performance via the accuracy score as in the Iris dataset.
# Which classifier(s) perform(s) the best and worst, and why?
#
# The classifiers include:
# * perceptron
# * logistic regression
# * SVM
# * decision tree
# * random forest
# * KNN
#
# The dataset is available as part of scikit learn, as follows.

# %%
from sklearn.datasets import load_digits
digits = load_digits()

X = digits.data # training data
y = digits.target # training label

print(X.shape)
print(y.shape)
# Out:
# (1797, 64)
# (1797,)

# %%
import matplotlib.pyplot as plt
import pylab as pl
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150
num_rows = 4
num_cols = 5
fig, ax = plt.subplots(nrows=num_rows, ncols=num_cols, sharex=True, sharey=True)
ax = ax.flatten()
for index in range(num_rows*num_cols):
    img = digits.images[index]
    label = digits.target[index]
    ax[index].imshow(img, cmap='Greys', interpolation='nearest')
    ax[index].set_title('digit ' + str(label))
ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# Date Preprocessing
#
# Hint: Divide training and test data set and apply other techinques we have learned if needed.

# %%
#Your code comes here
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# Classifier #1 Perceptron

# %%
#Your code, including traing and testing, to observe the accuracies.
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
ppn = Perceptron(eta0=0.1, random_state = 1)
ppn.fit(X_train_std, y_train)
y_pred = ppn.predict(X_test_std)
accuracy_ppn = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % accuracy_ppn)
# Out:
# Accuracy: 0.933

# %% [markdown]
# Classifier #2 Logistic Regression

# %%
#Your code, including traing and testing, to observe the accuracies.
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression(C=100.0, solver='liblinear')
lr.fit(X_train_std, y_train)
y_pred = lr.predict(X_test_std)
accuracy_lr = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % accuracy_lr)
# Out:
# Accuracy: 0.956

# %% [markdown]
# Classifier #3 SVM

# %%
#Your code, including traing and testing, to observe the accuracies.
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svm = SVC(kernel='linear', C=1, random_state=1)
svm.fit(X_train_std, y_train)
y_pred = svm.predict(X_test_std)
accuracy_svm = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % accuracy_svm)
# Out:
# Accuracy: 0.978

# %% [markdown]
# Classifier #4 Decision Tree

# %%
#Your code, including traing and testing, to observe the accuracies.
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
tree = DecisionTreeClassifier(criterion='gini', max_depth=15, random_state=1)
tree.fit(X_train_std, y_train)
y_pred = tree.predict(X_test_std)
accuracy_tree = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % accuracy_tree)
# Out:
# Accuracy: 0.856

# %% [markdown]
# Classifer #5 Random Forest

# %%
#Your code, including traing and testing, to observe the accuracies.
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
forest = RandomForestClassifier(criterion='gini', n_estimators=25, random_state=1, n_jobs=2)
forest.fit(X_train_std, y_train)
y_pred = forest.predict(X_test_std)
accuracy_forest = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % accuracy_forest)
# Out:
# Accuracy: 0.967

# %% [markdown]
# Classifier #6 KNN

# %%
#Your code, including traing and testing, to observe the accuracies.
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(X_train_std, y_train)
y_pred = knn.predict(X_test_std)
accuracy_knn = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % accuracy_knn)
# Out:
# Accuracy: 0.985

# %% [markdown]
# KNN performs the best, and the decision tree performs the worst.
#
# The decision tree is limited by the depth. If the depth is too deep, the classifier would be overfitting, if the depth is too shallow, the classifier would have high bias. It is hard to balance the depth.
#
# On this dataset, KNN is more accurate than other classifiers. KNN is care about the similarity, it memorizes the training data and make prediction based on this.

# %% [markdown]
# ###B3
# Build a spam classifier:
#
#
#
# *   Download examples of spam and ham from Apache SpamAssassin’s public datasets.
# *   Unzip the datasets and familiarize yourself with the data format.
# *   Split the datasets into a training set and a test set.
# *   Write a data preparation pipeline to convert each email into a feature vector. Your preparation pipeline should transform an email into a (sparse) vector that indicates the presence or absence of each possible word. For example, if all emails only ever contain four words, “Hello,” “how,” “are,” “you,” then the email “Hello you Hello Hello you” would be converted into a vector [1, 0, 0, 1] (meaning [“Hello” is present, “how” is absent, “are” is absent, “you” is present]), or [3, 0, 0, 2] if you prefer to count the number of occurrences of each word.
# *   You may want to add hyperparameters to your preparation pipeline to control whether or not to strip off email headers, convert each email to lowercase, remove punctuation, replace all URLs with “URL,” replace all numbers with “NUMBER,” or even perform stemming (i.e., trim off word endings; there are Python libraries available to do this).
#
# *   Finally, try out several classifiers and see if you can build a great spam classifier, with both high recall and high precision.

# %%
#Your answer here
import pandas as pd

import os 

DATASETS_DIR = 'datasets'
TAR_DIR = os.path.join(DATASETS_DIR, 'tar')

SPAM_URL = 'https://spamassassin.apache.org/old/publiccorpus/20050311_spam_2.tar.bz2'
EASY_HAM_URL = 'https://spamassassin.apache.org/old/publiccorpus/20030228_easy_ham_2.tar.bz2'
HARD_HAM_URL = 'https://spamassassin.apache.org/old/publiccorpus/20030228_hard_ham.tar.bz2'

from urllib.request import urlretrieve
import tarfile
import shutil


def make_dir():
  if not os.path.isdir(TAR_DIR):
    os.makedirs(TAR_DIR)

def download(url):

  filename = url.rsplit('/', 1)[-1]
  tarpath = os.path.join(TAR_DIR, filename)

  try:
    tarfile.open(tarpath)
  except:
    urlretrieve(url, tarpath)

  with tarfile.open(tarpath) as tar:
    dirname = os.path.join(DATASETS_DIR, tar.getnames()[0])
    if os.path.isdir(dirname):
      shutil.rmtree(dirname)
    tar.extractall(path=DATASETS_DIR)
        
    cmds_path = os.path.join(dirname, 'cmds')
    if os.path.isfile(cmds_path):
      os.remove(cmds_path)
  
  return dirname

# %%
make_dir()
spam_dir = download(SPAM_URL)
easy_ham_dir = download(EASY_HAM_URL)
hard_ham_dir = download(HARD_HAM_URL)
print(spam_dir)
# Out:
# datasets/spam_2

# %%
import numpy as np
import glob

def load_dataset(dirpath):
  files = []
  filepaths = glob.glob(dirpath + '/*')
  print(dirpath)
  for path in filepaths:
    with open(path, 'rb') as f:
      byte_content = f.read()
      str_content = byte_content.decode('utf-8', errors='ignore')
      files.append(str_content)
  
  return files

# %%
spam = load_dataset(spam_dir)
easy_ham = load_dataset(easy_ham_dir)
hard_ham = load_dataset(hard_ham_dir)
# Out:
# datasets/spam_2
# datasets/easy_ham_2
# datasets/hard_ham

# %%
print(spam[0])
print('----')
print(easy_ham[0])
# Out:
# From mort239o@pac25.westernbarge.com  Mon Jun 24 17:06:38 2002
# Return-Path: mort239o@pac25.westernbarge.com
# Delivery-Date: Sun May 26 01:37:53 2002
# Received: from mandark.labs.netnoteinc.com ([213.105.180.140]) by
#     dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g4Q0bqe25942 for
#     <jm@jmason.org>; Sun, 26 May 2002 01:37:52 +0100
# Received: from pac25.westernbarge.com ([67.96.136.25]) by
#     mandark.labs.netnoteinc.com (8.11.2/8.11.2) with ESMTP id g4Q0bo714373 for
#     <jm@netnoteinc.com>; Sun, 26 May 2002 01:37:51 +0100
# Date: Sat, 25 May 2002 17:38:52 -0400
# Message-Id: <200205252138.g4PLcpn30532@pac25.westernbarge.com>
# From: mort239o@pac25.westernbarge.com
# To: jgzqbsmouk@pac25.westernbarge.com
# Reply-To: mort239o@pac25.westernbarge.com
# Subject: ADV: Life Insurance - Pennies a day! -- FREE Quote cmgpk
# X-Keywords:
#
# Low-Cost Term-Life Insurance!
# SAVE up to 70% or more on your term life insurance policy now.
#
# CLICK HERE NOW For your FREE Quote!
# ...

# %%
import sklearn.utils
X = spam+easy_ham+hard_ham
y = np.concatenate((np.ones(len(spam)), np.zeros(len(easy_ham) + len(hard_ham))))

X, y = sklearn.utils.shuffle(X, y, random_state=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
print(len(X_train), len(y_train))
print(len(X_test), len(y_test))
# Out:
# 2132 2132
# 914 914

# %% [markdown]
# Write a data preparation pipeline to convert each email into a feature vector. Your preparation pipeline should transform an email into a (sparse) vector that indicates the presence or absence of each possible word. For example, if all emails only ever contain four words, “Hello,” “how,” “are,” “you,” then the email “Hello you Hello Hello you” would be converted into a vector [1, 0, 0, 1] (meaning [“Hello” is present, “how” is absent, “are” is absent, “you” is present]), or [3, 0, 0, 2] if you prefer to count the number of occurrences of each word.
#
#
# You may want to add hyperparameters to your preparation pipeline to control whether or not to strip off email headers, convert each email to lowercase, remove punctuation, replace all URLs with “URL,” replace all numbers with “NUMBER,” or even perform stemming (i.e., trim off word endings; there are Python libraries available to do this).

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import re

class ProcessedEmail(BaseEstimator, TransformerMixin):
  def __init__(self, to_remove_header=True, to_lowcase=True, to_remove_punctuation=True, convert_url=True, convert_num=True):
    self.to_remove_header = to_remove_header
    self.to_lowcase = to_lowcase
    self.to_remove_punctuation = to_remove_punctuation
    self.convert_url = convert_url
    self.convert_num = convert_num

  def fit(self, X, y=None):
    return self

  def transform(self, X, y=None):
    X_processed = []
    for email in X:

      if self.to_remove_header:
        email = email[email.index('\n\n'):]

      if self.to_lowcase:
        email = email.lower()

      if self.to_remove_punctuation:
        no_pun_mail = ""
        for c in email:
          if c.isalnum() or c.isspace():
            no_pun_mail += c
        email = no_pun_mail

      email_words = email.split()
      if self.convert_url:
        for i, word in enumerate(email_words):
          if re.match("http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|"
                     "[!*\(\), ]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", word) is not None:
            email_words[i] = 'URL'

      if self.convert_num:
        for i, word in enumerate(email_words):
          if word.isdigit():
            email_words[i] = 'NUMBER'
            
      email = ' '.join(email_words)
      X_processed.append(email)
    return X_processed

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer

preparation_pipeline = Pipeline([('processed_email', ProcessedEmail()), ('bag_of_words', CountVectorizer())])

X_train_prepared = preparation_pipeline.fit_transform(X_train)
X_test_prepared = preparation_pipeline.transform(X_test)

# %%
print(X_train_prepared.shape)
print(X_test_prepared.shape)
# Out:
# (2132, 89888)
# (914, 89888)

# %% [markdown]
# - perceptron
# - logistic regression
# - SVM
# - decision tree
# - random forest
# - KNN

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score

classifiers = {
    'perceptron': Perceptron(random_state=1),
    'lr': LogisticRegression(solver='liblinear'),
    'SVM': SVC(kernel='linear', random_state=1),
    'Decision Tree': DecisionTreeClassifier(criterion='gini',  random_state=1),
    'Random Forest': RandomForestClassifier(criterion='gini', random_state=1),
    'KNN': KNeighborsClassifier(metric='minkowski')
}

y_train_preds = {}

for name, classifier in classifiers.items():
  y_train_preds[name] = cross_val_predict(classifier, X_train_prepared, y_train, cv=10)

# %%
from sklearn.metrics import precision_score, recall_score

for name, y_pred in y_train_preds.items():
  print('Classifier: %s' % name)
  print('Score: %.3f' % accuracy_score(y_train, y_pred))
  print('Precision: %.3f' % precision_score(y_true=y_train, y_pred=y_pred))
  print('Recall: %.3f' % recall_score(y_true=y_train, y_pred=y_pred))
  print("----")
# Out:
# Classifier: perceptron
# Score: 0.961
# Precision: 0.965
# Recall: 0.949
# ----
# Classifier: lr
# Score: 0.970
# Precision: 0.962
# Recall: 0.973
# ----
# Classifier: SVM
# Score: 0.967
# Precision: 0.962
# Recall: 0.966
# ----
# Classifier: Decision Tree
# Score: 0.923
# Precision: 0.903
# Recall: 0.931
# ----
# Classifier: Random Forest
# Score: 0.969
# Precision: 0.956
# Recall: 0.976
# ----
# Classifier: KNN
# Score: 0.907
# Precision: 0.890
# Recall: 0.910
# ----

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

#  fine tuning 
#  lr, svm, random Forest

pipe_lr = LogisticRegression(solver='liblinear')
gs = GridSearchCV(estimator=pipe_lr, param_grid=[{'C': [1, 10, 50, 100]}], scoring='accuracy', cv=2)
# scores = cross_val_score(gs, X_train_prepared, y_train, scoring='accuracy', cv=5)
# print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
gs = gs.fit(X_train_prepared, y_train)
print("lr:")
print(gs.best_score_)
print(gs.best_params_)
bs_lr = gs.best_estimator_
y_pred = cross_val_predict(bs_lr, X_train_prepared, y_train, cv=10)
print('Score: %.3f' % accuracy_score(y_train, y_pred))
print('Precision: %.3f' % precision_score(y_true=y_train, y_pred=y_pred))
print('Recall: %.3f' % recall_score(y_true=y_train, y_pred=y_pred))
# Out:
# lr:
# 0.9681050656660413
# {'C': 1}
# Score: 0.970
# Precision: 0.962
# Recall: 0.973

# %%
pipe_svm = SVC(kernel='linear', random_state=1)
gs = GridSearchCV(estimator=pipe_svm, param_grid=[{'C': [1, 10, 50, 100]}], scoring='accuracy', cv=2)
gs = gs.fit(X_train_prepared, y_train)
print("svm:")
print(gs.best_score_)
print(gs.best_params_)
bs_svm = gs.best_estimator_
y_pred = cross_val_predict(bs_svm, X_train_prepared, y_train, cv=10)
print('Score: %.3f' % accuracy_score(y_train, y_pred))
print('Precision: %.3f' % precision_score(y_true=y_train, y_pred=y_pred))
print('Recall: %.3f' % recall_score(y_true=y_train, y_pred=y_pred))
# Out:
# svm:
# 0.9620075046904315
# {'C': 1}
# Score: 0.967
# Precision: 0.962
# Recall: 0.966

# %%
pipe_rt = RandomForestClassifier(criterion='gini',
                                 random_state=1, n_jobs=2)
gs = GridSearchCV(estimator=pipe_rt, param_grid=[{'n_estimators': [10, 20, 30, 40, 50, 60, 70, 80, 100]}], scoring='accuracy', cv=2)
gs = gs.fit(X_train_prepared, y_train)
print("random_tree:")
print(gs.best_score_)
print(gs.best_params_)
bs_rt = gs.best_estimator_
y_pred = cross_val_predict(bs_rt, X_train_prepared, y_train, cv=10)
print('Score: %.3f' % accuracy_score(y_train, y_pred))
print('Precision: %.3f' % precision_score(y_true=y_train, y_pred=y_pred))
print('Recall: %.3f' % recall_score(y_true=y_train, y_pred=y_pred))
# Out:
# random_tree:
# 0.9620075046904315
# {'n_estimators': 40}
# Score: 0.967
# Precision: 0.958
# Recall: 0.970

# %% [markdown]
# Choose Lr

# %%
y_test_pred = bs_lr.predict(X_test_prepared)
print('Score: %.3f' % accuracy_score(y_test, y_test_pred))
print('Precision: %.3f' % precision_score(y_true=y_test, y_pred=y_test_pred))
print('Recall: %.3f' % recall_score(y_true=y_test, y_pred=y_test_pred))
# Out:
# Score: 0.978
# Precision: 0.969
# Recall: 0.983
